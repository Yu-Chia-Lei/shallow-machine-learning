# %% [markdown]
# <hr>
#
# #### <strong>第四次作品：去除影像模糊的深度學習實驗</strong>
#
# 學號：
#
# 姓名：

# %% [markdown]
# <hr>
#
#  **<font color=darkgoldenrod>作品目標</font>**：
#
# 本作品以超解析度卷積神經網路（Super-Resolution Convolutional Neural Network, SRCNN）為基礎，探討其於影像去模糊（Image Deblurring）任務中的可行性與效能表現。研究內容包含多種網路結構之比較、不同訓練影像資料量與影像尺寸對模型性能的影響，以及訓練強度等超參數之調整。透過測試影像與隨機選取之實際照片進行評估，本作品分析各模型於去模糊品質、穩定性與泛化能力上的差異，藉以驗證不同設計與訓練策略對影像復原效果之影響。<font color=red>（optional:）此外，除本實驗訓練的模型外，同時與目前已公開的其他預訓練模型比較，做為訓練成果的參考。</font>

# %% [markdown]
# <hr>
#
#  **<font color=darkgoldenrod>實驗計畫</font>**：
#
#  在此表達本次實驗將使用那些模型？哪些訓練影像？、、、等細節及如何執行、如何比較、、、，譬如
#
# - 關於訓練資料：來源、數量、是否進行任何前處理、、、等。
# - 關於 CNN 模型的結構：可以說明嘗試過哪些模型及最後定案的模型、、、等。
# - 其他：模模程度、loss function, optimizer, epochs, batch size, 、、、等選擇。
# - 前述關於本實驗之細節，請特別標示出（譬如不同顏色字體）與上課用的示範程式不同之處，意即你做了哪些改變？進行了那些實驗？達到了甚麼效果？、、、。
#
# 結果呈現：（供參酌，並請適當改寫以下文字以配合實際完成的成果）
#
# - 儲存欲進行比較模型的 pre-trained 檔，方便比較。
# - 讀入每個 pre-trained 的 pt 檔（已進行過 N 次 epochs），執行 2 個 epochs，並展示其 Train PSNR 與 Val PSNR 值。以此展現預訓練的成果。
# - 測試 Set5 與 Set14 並展示 Test PSNR on Set5 與 Test PSNR on Set14。亦即先將 Set5 與 set14 共 19 張影像模糊化（blurring）後，再開啟前面已訓練好的模型，輸出去模糊圖，最後並與模糊圖對照輸出。即每列圖可輸出三張，依序為原始清晰圖、模糊圖、去模糊圖，共 19 x 3 張圖。
# - 寫一段程式實際對已訓練完成的 Deblurring CNN 模型，輸入任何一張自己挑選的影像（sharp），將之模糊化（blurred）後輸入模型得到去模糊化圖像（deblurred），最後繪製原始清晰圖、模糊圖及去模糊圖共三張，並計算 blurred 與 deblurred 兩者的 psnr 值以供對比。
# - 、、、

# %% [markdown]
# <hr>
#
# **<font color=darkgoldenrod>預先載入套件：</font>**

# %%
# Import packages

# %% [markdown]
# **<font color=darkgoldenrod>預先載入共用函數（def）</font>**

# %%
# 自訂之共用函數（def）可以放在這裡（函數名稱自取，但必須符合函數目的），譬如：

# %% [markdown]
# **<font color=darkgoldenrod>實驗開始</font>**

# %% [markdown]
# <hr>
#
# **<font color=darkgoldenrod>總結論：</font>**
